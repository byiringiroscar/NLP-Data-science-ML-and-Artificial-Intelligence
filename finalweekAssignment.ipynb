# %% [markdown]
# <a href="https://colab.research.google.com/github/byiringiroscar/NLP_FELLOWSHIP/blob/main/finalweekAssignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('Eng_Kin-Paralleldata.csv')
df.head(10)
# Out:
#             ID                                            English  \
# 0  ID_IFVTMXW8        F_all back to threading messages by subject
# 1  ID_SBXUPXE3  You will have to restart GIMP for the followin...
# 2  ID_ZOCZ3PXQ  The radio button whose group this widget belon...
# 3  ID_6AVBJ1YS           Print all subdirectories in a directory.
# 4  ID_FW4V44WK  Paste the contents of the clipboard as a new i...
# 5  ID_36U2WH67        Missing cdr from pair of values in XML file
# 6  ID_GW7Z5SWN  Click to erase the log file display and the lo...
# 7  ID_WAKIPQJ5          Jump to the previous bookmark in the file
# 8  ID_5DBJFT52  Display information about the templates, varia...
# 9  ID_2XERJBUD  The Space key is used for two things, when mus...
#
#                                          Kinyarwanda
# 0                 Inyuma Kuri Ubutumwa ku Ikivugwaho
# 1  Kuri Ongera utangire kugirango i Amahinduka Ku...
# 2                       Akabuto bya Itsinda iyi Kuri
# ...
